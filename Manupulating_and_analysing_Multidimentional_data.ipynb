# %% [markdown]
# <a href="https://colab.research.google.com/github/surajgazi100/Data_science_Fundamentals/blob/main/Manupulating_and_analysing_Multidimentional_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   scienrific Multidimentional Data
# *   ingest and Data Management
#
#
# *   Analytics and visualization
# *   extendinding  analtytics capabilities using python
#
#
# *   sharing services and web application

# %% [markdown]
# > Scientific Multidimentional data
#
# ---
#
#
# *   Stored in netCFD ,GRIB and HDF formats
#
# *   Multidimentional
#
#
# ![6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![8.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![9.png](data:image/png;base64,...)

# %% [markdown]
# ![10.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Data Analysis using Pandas![series-and-dataframe.width-1200.png](data:image/png;base64,...)

# %% [markdown]
# Examples

# %%
pip install pandas

# %%
import pandas as pd
numbers = {1,2,3,4,5}
ser = pd.Series(list(numbers))
print(ser)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df = pd.DataFrame({'foo':['x','y','z'],
                   'bsr': [6,10,None],
                   'baz':[True,True,False]})
print(df)
# Out:
#   foo   bsr    baz
# 0   x   6.0   True
# 1   y  10.0   True
# 2   z   NaN  False

# %% [markdown]
# Handling Mising values

# %%
new_def = df.dropna(how='all')

# %% [markdown]
# Filling the default values

# %%
new_def = df.fillna(method='ffill')

# %% [markdown]
# Indexing

# %%
df.loc['a']
df.iloc[0]

# %%
df.set_index([['one','one','two','two'],df.index])

# %%
one = df.loc['one','a']

# %% [markdown]
# Statistics

# %%
df.describe()
# Out:
#              bsr
# count   2.000000
# mean    8.000000
# std     2.828427
# min     6.000000
# 25%     7.000000
# 50%     8.000000
# 75%     9.000000
# max    10.000000

# %%
df.cov()
# Out:
#      bsr       baz
# bsr  8.0  0.000000
# baz  0.0  0.333333

# %%
df.corr()
# Out:
#      bsr  baz
# bsr  1.0  NaN
# baz  NaN  1.0

# %%
df.rank()
# Out:
#    foo  bsr  baz
# 0  1.0  1.0  2.5
# 1  2.0  2.0  2.5
# 2  3.0  NaN  1.0

# %%
df.cumsum
# Out:
# <bound method DataFrame.cumsum of   foo   bsr    baz
# 0   x   6.0   True
# 1   y  10.0   True
# 2   z   NaN  False>
