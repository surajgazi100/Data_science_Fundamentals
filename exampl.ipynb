# %% [markdown]
# <a href="https://colab.research.google.com/github/surajgazi100/Data_science_Fundamentals/blob/main/exampl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Make every voice heard with natural language processing![banner-neurolinguistic-programming-nlp-vector-260nw-1257901324.webp](data:image/webp;base64,...)

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))
 
sum = a + b
 
print("sum:", sum)
